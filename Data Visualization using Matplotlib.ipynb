# %%
import pandas as pd
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(np.linspace(-1,1,50), np.random.randn(50))

# %%
pip install openpyxl
# Out:
# ...
#
# ...

# %%
data = pd.read_excel("C:/Users/DELL/Desktop/python/population.xlsx")
data.head(6)
# Out:
#          Country  Population Yearly Change  Net Change  Density (P/Km²)  \
# 0          China  1440297825        0.39 %     5540090              153
# 1          India  1382345085        0.99 %    13586631              464
# 2  United States   331341050        0.59 %     1937734               36
# 3      Indonesia   274021604        1.07 %     2898047              151
# 4       Pakistan   221612785        2.00 %     4327022              287
# 5         Brazil   212821986        0.72 %     1509890               25
#
#    Land Area (Km²)  Migrants (net) Fert. Rate Med. Age Urban Pop % World Share
# 0          9388211       -348399.0        1.7       38        61 %     18.47 %
# 1          2973190       -532687.0        2.2       28        35 %     17.70 %
# 2          9147420        954806.0        1.8       38        83 %      4.25 %
# 3          1811570        -98955.0        2.3       30        56 %      3.51 %
# ...

# %%
data_sorted = data.sort_values('Population', ascending=False)
data_sorted.head(10).plot.barh('Country', 'Population', figsize=(10, 6))
# Out:
# <AxesSubplot: ylabel='Country'>

# %%
titanic = pd.read_excel("C:/Users/DELL/Desktop/python/tested.xlsx")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         1     3.0
# 1            893         1     3.0
# 2            894         0     2.0
# 3            895         1     3.0
# 4            896         1     3.0
# ..           ...       ...     ...
# 413         1305         0     3.0
# 414         1306         1     1.0
# 415         1307         0     3.0
# 416         1308         0     3.0
# 417         1309         0     3.0
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic.groupby('Sex').Survived.sum().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Sex'>

# %%
data_pie = titanic.groupby('Pclass').Ticket.count()
plt.pie(np.array(data_pie), labels=("Pclass-1", "Pclass-2", "Pclass-3"), explode= (0, 0, 0.1), shadow = True, autopct='%d%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1502b955750>,
# ...
#  [Text(0.767495298098289, 0.7880044209247932, 'Pclass-1'),
#   Text(-0.7311034749275591, 0.8218805928776077, 'Pclass-2'),
#   Text(-0.08581190551780205, -1.1969278661938672, 'Pclass-3')],
#  [Text(0.4186337989627031, 0.4298205932317053, '25%'),
#   Text(-0.3987837135968504, 0.4482985052059678, '22%'),
#   Text(-0.05005694488538452, -0.6982079219464226, '52%')])

# %%
titanic.boxplot(column = 'Fare', by='Pclass')
# Out:
# <AxesSubplot: title={'center': 'Fare'}, xlabel='Pclass'>

# %%
titanic.Fare.hist(bins = 50)
# Out:
# <AxesSubplot: >
